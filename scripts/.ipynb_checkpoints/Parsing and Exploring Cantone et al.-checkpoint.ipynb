# %% [markdown]
# # Cantone et al.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from scipy.interpolate import interp1d

# %%
import sys
from datetime import datetime
import numpy as np

import networkx as nx
from nxpd import draw
from nxpd import nxpdParams
nxpdParams['show'] = 'ipynb'

sys.path.append("../pipelines")
import Pipelines as tdw
import Swing.util.lag_identification as lag_id
from Swing.util.Evaluator import Evaluator

# %% [markdown]
# ## Switch-On Data

# %%
raw_data = pd.read_csv('../data/invitro/cantone_switchon_raw_timeseries.tsv', sep = '\t')
raw_data = raw_data.set_index('Time')

# %%
# Manually splitting up dataframe into separate experiments
experiments = []
experiments.append(raw_data[0:11])
experiments.append(raw_data[11:26])
experiments.append(raw_data[26:36])
experiments.append(raw_data[36:46])
experiments.append(raw_data[46:62])

# %%
f, axarr = plt.subplots(5, sharex=True)
f.set_size_inches(18.5, 10.5)
for idx,exp in enumerate(experiments):
    for col in exp:
        gene_name = exp[col].name
        axarr[idx].plot(exp[col], '.-')
        axarr[idx].set_ylim([0,0.08])

# %% [markdown]
# #### Notes about plot above
# - Exp 2 is missing time 0. Fill in with the mean of time 0 of the rest of the trials.
# - Trials 1,3,4 are not as long as trials 2 and 5. Possibly use the mean of the trials 2 and 5 to fill in trials 1, 3, 4.
# - There is a great deal of variation between all the "time-series." Remember that qRT-PCR is an endpoint experiment, so the datapoints aren't true time series.

# %% [markdown]
# ##### Impute Experiment 2 Time 0

# %%
means = raw_data[raw_data.index==0].mean()
exp_2 = raw_data[11:26]

exp_2.loc[0] = means
exp_2 = exp_2.sort()

experiments = []
experiments.append(raw_data[0:11])
experiments.append(exp_2)
experiments.append(raw_data[26:36])
experiments.append(raw_data[36:46])
experiments.append(raw_data[46:62])

f, axarr = plt.subplots(5, sharex=True)
f.set_size_inches(18.5, 10.5)
for idx,exp in enumerate(experiments):
    for col in exp:
        gene_name = exp[col].name
        axarr[idx].plot(exp[col], '.-')
        axarr[idx].set_ylim([0,0.08])
# Out:
# /Users/jjw036/anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jjw036/anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:5: FutureWarning: sort(....) is deprecated, use sort_index(.....)

# %% [markdown]
# ##### Interpolate all experiments up to t=170

# %%
xi = np.linspace(0,170, num=18)
f, axarr = plt.subplots(5, sharex=True)
f.set_size_inches(18.5, 10.5)
colors = ['red', 'green', 'blue', 'purple', 'black']

exp_inter = pd.DataFrame()

for idx,exp in enumerate(experiments):    
    interpolated_df = pd.DataFrame()
    for idx2, col in enumerate(exp):        
        #graph and save interpolated series
        gene_name = exp[col].name
        
        #interpolate
        linear = interp1d(exp.index, exp[col])
        cubic = interp1d(exp.index, exp[col], kind='cubic')
        #axarr[idx].plot(exp[col], 'o', xi, linear(xi), '-', xi, cubic(xi), '--')
        
        #plot interpolation
        axarr[idx].plot(exp[col], 'o', color = colors[idx2])     
        axarr[idx].plot(xi, cubic(xi), '--', color = colors[idx2])
        interpolated_df[gene_name] = cubic(xi)
        
        #add indices
        interpolated_df.index = xi   
        interpolated_df.index.name = 'Time'
    exp_inter = exp_inter.append(interpolated_df)
    
print(exp_inter)
with open('../data/invitro/cantone_switchon_interpolated_timeseries.tsv', 'w') as out:
    exp_inter.to_csv(out, sep='\t')
# Out:
#           CBF1      GAL4      SWI5     GAL80      ASH1
# Time
# 0     0.000338  0.007340  0.004566  0.006024  0.010167
# 10    0.003412  0.030501  0.007977  0.016232  0.006872
# 20    0.009506  0.043535  0.011714  0.026625  0.013093
# 30    0.018011  0.047202  0.029157  0.029770  0.020833
# 40    0.026723  0.042713  0.062874  0.021682  0.023663
# 50    0.028262  0.033032  0.078836  0.010525  0.021197
# 60    0.017911  0.021972  0.050282  0.005205  0.016169
# 70    0.006778  0.014989  0.016120  0.005448  0.017763
# 80    0.005775  0.015649  0.017067  0.008669  0.031303
# 90    0.009227  0.018326  0.035403  0.012217  0.040246
# 100   0.009425  0.017179  0.044623  0.014045  0.030787
# 110   0.007139  0.014731  0.041521  0.014579  0.021944
# 120   0.005230  0.014381  0.030543  0.014618  0.032677
# 130   0.006434  0.014680  0.023438  0.013985  0.048867
# 140   0.011715  0.014039  0.029819  0.012300  0.052818
# 150   0.015041  0.015145  0.043435  0.009355  0.045594
# 160   0.011926  0.020396  0.055582  0.005624  0.033271
# 170   0.011049  0.026737  0.063592  0.004143  0.023196
# 0     0.002700  0.005292  0.004074  0.004421  0.011470
# 10    0.003582  0.010972  0.001396  0.011203  0.006457
# 20    0.003553  0.017868  0.002001  0.012344  0.004220
# 30    0.002981  0.020193  0.005208  0.010027  0.003975
# 40    0.002303  0.014994  0.009884  0.006503  0.004890
# 50    0.002175  0.009163  0.013369  0.004129  0.006066
# 60    0.003068  0.009431  0.013526  0.004404  0.006957
# 70    0.004487  0.012049  0.011842  0.005299  0.008520
# 80    0.005737  0.012163  0.010573  0.004872  0.011288
# 90    0.006280  0.011010  0.011438  0.005048  0.012604
# 100   0.005912  0.010702  0.014994  0.007547  0.010664
# 110   0.005601  0.010784  0.017701  0.009388  0.010273
# ...        ...       ...       ...       ...       ...
# 60    0.004081  0.009088  0.030490  0.006339  0.021015
# 70    0.004661  0.010859  0.040246  0.007189  0.023196
# 80    0.006221  0.015442  0.052365  0.008705  0.029650
# 90    0.007840  0.017763  0.054598  0.009453  0.034435
# 100   0.008482  0.013574  0.039125  0.008352  0.031747
# 110   0.008032  0.007813  0.022718  0.006778  0.026369
# 120   0.007028  0.006048  0.022135  0.006353  0.024034
# 130   0.007705  0.007214  0.029462  0.007239  0.023683
# 140   0.011867  0.008898  0.033209  0.009089  0.023387
# 150   0.017886  0.009958  0.032240  0.010972  0.024518
# 160   0.023022  0.009825  0.029263  0.011818  0.029684
# 170   0.023519  0.008974  0.032017  0.010562  0.043135
# 0     0.003097  0.003285  0.002315  0.003721  0.006108
# 10    0.004893  0.059954  0.010672  0.038741  0.022251
# 20    0.005337  0.058697  0.020370  0.057306  0.019214
# 30    0.004534  0.035773  0.025383  0.055169  0.011399
# 40    0.002888  0.019970  0.022223  0.033232  0.009552
# 50    0.001803  0.013276  0.016402  0.010202  0.011518
# 60    0.002375  0.011356  0.014197  0.003340  0.013309
# 70    0.003460  0.011399  0.015953  0.006324  0.016516
# 80    0.003787  0.011383  0.019884  0.009029  0.022514
# 90    0.003799  0.010934  0.021605  0.009702  0.026233
# 100   0.004169  0.010099  0.018016  0.008816  0.023331
# 110   0.004759  0.008974  0.013745  0.007366  0.018841
# 120   0.005416  0.007666  0.013486  0.006234  0.018112
# 130   0.006708  0.006280  0.014478  0.005318  0.018389
# 140   0.009080  0.005185  0.013639  0.004637  0.016572
# 150   0.011760  0.005819  0.014082  0.005680  0.016289
# 160   0.013693  0.008866  0.018490  0.009137  0.020514
# 170   0.013936  0.010934  0.021642  0.011049  0.022876
#
# [90 rows x 5 columns]

# %% [markdown]
# ## Switch-Off Data

# %%
raw_data = pd.read_csv('../data/invitro/cantone_switchoff_raw_timeseries.tsv', sep = '\t')
raw_data = raw_data.set_index('Time')

# Manually splitting up dataframe into separate experiments
experiments = []
experiments.append(raw_data[0:19])
experiments.append(raw_data[19:38])
experiments.append(raw_data[38:59])
experiments.append(raw_data[59:80])

# %%
f, axarr = plt.subplots(4, sharex=True)
f.set_size_inches(18.5, 10.5)
for idx,exp in enumerate(experiments):
    for col in exp:
        gene_name = exp[col].name
        axarr[idx].plot(exp[col], '.-')
        axarr[idx].set_ylim([0,0.3])

# %% [markdown]
# ##### Notes:
# - No interpolation necessary
# - Time-series ends at 180 for exp 1 and 2 and 200 for exp 3 and 4
# - Large variation between time series. May need to be normalized.
# - Time-series will be truncated at 170 for comparison to switch-on time-series data.

# %%
parsed_data = raw_data[(raw_data.index >= 0) & (raw_data.index <= 170)]

with open('../data/invitro/cantone_switchoff_interpolated_timeseries.tsv', 'w') as out:
    parsed_data.to_csv(out, sep='\t')

# %% [markdown]
# #### Testing SWING

# %%
data_folder = "../data/invitro/Dionesus"
file_path = "../data/invitro/cantone_switchon_interpolated_timeseries.tsv"
current_time = datetime.time
run_params = {'data_folder': data_folder,
              'file_path':file_path,
              'td_window':17,
              'min_lag':1,
              'max_lag':1,
              'n_trees':100,
              'permutation_n':10,
              'lag_method':'mean_mean',
              'calc_mse':False,
              'bootstrap_n':1000,
              'n_trials':1,
              'run_time':current_time,
              'sort_by':'rank',
              'iterating_param':'td_window',
              'filter_noisy': False
              }
            
window_sizes = list(range(2,19))
roc_list = []
pr_list = []

for window_size in window_sizes:
    print("window_size:",window_size)
    run_params['td_window'] = window_size
    if window_size == 18:
        run_params['min_lag'] =0
        run_params['max_lag'] = 0
    roc,pr, tdr = tdw.get_td_stats(**run_params)
    roc_list.append(roc)
    pr_list.append(pr)
# Out:
# window_size: 2
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# /Users/jjw036/Roller/Swing/Swing.py:573: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   current_df.sort(['adj_imp'], ascending=False, inplace=True)
# /Users/jjw036/Roller/Swing/Swing.py:699: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   sort_df.sort(sort_field, ascending=True, inplace=True)
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.489583333333
# 0.354154699467
# window_size: 3
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.447916666667
# 0.337424554612
# window_size: 4
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.479166666667
# 0.346988948551
# window_size: 5
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.59375
# 0.404992576868
# window_size: 6
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.625
# 0.38750225469
# window_size: 7
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.614583333333
# 0.383841102729
# window_size: 8
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.625
# 0.398763480671
# window_size: 9
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.666666666667
# 0.426718338851
# window_size: 10
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.697916666667
# 0.442252886003
# window_size: 11
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.729166666667
# 0.477401938339
# window_size: 12
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.75
# 0.491554279054
# window_size: 13
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.802083333333
# 0.563839285714
# window_size: 14
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.802083333333
# 0.633894751082
# window_size: 15
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.791666666667
# 0.619029846787
# window_size: 16
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.8125
# 0.663632119514
# window_size: 17
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.822916666667
# 0.627455357143
# window_size: 18
# ['Time', 'CBF1', 'GAL4', 'SWI5', 'GAL80', 'ASH1']
# Compiling all model edges...
# [DONE]
# Lumping edges...
# [DONE]
# Calculating rank edge importance...
# [DONE]
# 20
# Scoring model...
# [DONE]
# 0.78125
# 0.691446665542

# %%
plt.plot(window_sizes,roc_list)
plt.xlabel("window size")
plt.ylabel("AUROC")
plt.figure()
plt.plot(window_sizes,pr_list)
plt.xlabel("window size")
plt.ylabel("AUPR")

# %%
exp_inter = lag_id.get_experiment_list("../data/invitro/cantone_switchon_interpolated_timeseries.tsv", timepoints=18, perturbs=5)
# Out:
# [             CBF1    GAL4    SWI5   GAL80    ASH1
#  Time
#  0.00000   0.00034 0.00734 0.00457 0.00602 0.01017
#  10.00000  0.00341 0.03050 0.00798 0.01623 0.00687
#  20.00000  0.00951 0.04354 0.01171 0.02663 0.01309
#  30.00000  0.01801 0.04720 0.02916 0.02977 0.02083
#  40.00000  0.02672 0.04271 0.06287 0.02168 0.02366
#  50.00000  0.02826 0.03303 0.07884 0.01053 0.02120
#  60.00000  0.01791 0.02197 0.05028 0.00521 0.01617
#  70.00000  0.00678 0.01499 0.01612 0.00545 0.01776
#  80.00000  0.00578 0.01565 0.01707 0.00867 0.03130
#  90.00000  0.00923 0.01833 0.03540 0.01222 0.04025
#  100.00000 0.00942 0.01718 0.04462 0.01404 0.03079
#  110.00000 0.00714 0.01473 0.04152 0.01458 0.02194
#  120.00000 0.00523 0.01438 0.03054 0.01462 0.03268
#  130.00000 0.00643 0.01468 0.02344 0.01398 0.04887
#  140.00000 0.01171 0.01404 0.02982 0.01230 0.05282
#  150.00000 0.01504 0.01515 0.04343 0.00936 0.04559
#  160.00000 0.01193 0.02040 0.05558 0.00562 0.03327
#  170.00000 0.01105 0.02674 0.06359 0.00414 0.02320,
#               CBF1    GAL4    SWI5   GAL80    ASH1
#  Time
#  0.00000   0.00270 0.00529 0.00407 0.00442 0.01147
#  10.00000  0.00358 0.01097 0.00140 0.01120 0.00646
#  20.00000  0.00355 0.01787 0.00200 0.01234 0.00422
#  30.00000  0.00298 0.02019 0.00521 0.01003 0.00397
#  40.00000  0.00230 0.01499 0.00988 0.00650 0.00489
#  50.00000  0.00217 0.00916 0.01337 0.00413 0.00607
#  60.00000  0.00307 0.00943 0.01353 0.00440 0.00696
#  70.00000  0.00449 0.01205 0.01184 0.00530 0.00852
#  80.00000  0.00574 0.01216 0.01057 0.00487 0.01129
#  90.00000  0.00628 0.01101 0.01144 0.00505 0.01260
#  100.00000 0.00591 0.01070 0.01499 0.00755 0.01066
#  110.00000 0.00560 0.01078 0.01770 0.00939 0.01027
#  120.00000 0.00632 0.01044 0.01675 0.00777 0.01562
#  130.00000 0.00784 0.01003 0.01635 0.00526 0.02179
#  140.00000 0.00988 0.01006 0.02016 0.00494 0.02390
#  150.00000 0.01300 0.01067 0.02272 0.00639 0.02610
#  160.00000 0.01735 0.01167 0.01893 0.00835 0.03210
#  170.00000 0.02055 0.01205 0.01453 0.00965 0.03479,
#               CBF1    GAL4    SWI5   GAL80    ASH1
#  Time
#  0.00000   0.00294 0.00458 0.00404 0.00432 0.01172
#  10.00000  0.00466 0.02164 0.00628 0.02091 0.01064
#  20.00000  0.00500 0.02153 0.01494 0.01904 0.00919
#  30.00000  0.00484 0.01546 0.02127 0.01148 0.00982
#  40.00000  0.00474 0.01250 0.02044 0.00795 0.01413
#  50.00000  0.00430 0.01370 0.02091 0.00749 0.02040
#  60.00000  0.00379 0.01726 0.02924 0.00713 0.02556
#  70.00000  0.00687 0.01801 0.03125 0.00646 0.02435
#  80.00000  0.01566 0.01238 0.01581 0.00583 0.01453
#  90.00000  0.02256 0.00668 0.00473 0.00600 0.00812
#  100.00000 0.02063 0.00728 0.01822 0.00733 0.01548
#  110.00000 0.01525 0.01071 0.03729 0.00829 0.02619
#  120.00000 0.01313 0.01218 0.04010 0.00753 0.02821
#  130.00000 0.01398 0.01124 0.03280 0.00632 0.02401
#  140.00000 0.01606 0.00883 0.02670 0.00627 0.01932
#  150.00000 0.01858 0.00714 0.02574 0.00760 0.01852
#  160.00000 0.02130 0.00861 0.03080 0.01005 0.02516
#  170.00000 0.02503 0.01546 0.03781 0.01278 0.04095,
#               CBF1    GAL4    SWI5   GAL80    ASH1
#  Time
#  0.00000   0.00443 0.00596 0.00537 0.00362 0.01789
#  10.00000  0.00576 0.03901 0.01101 0.02336 0.01351
#  20.00000  0.00517 0.03474 0.02651 0.02217 0.00867
#  30.00000  0.00419 0.01878 0.03742 0.01360 0.00776
#  40.00000  0.00391 0.01080 0.03470 0.00831 0.01299
#  50.00000  0.00402 0.00932 0.02846 0.00655 0.01904
#  60.00000  0.00408 0.00909 0.03049 0.00634 0.02101
#  70.00000  0.00466 0.01086 0.04025 0.00719 0.02320
#  80.00000  0.00622 0.01544 0.05237 0.00870 0.02965
#  90.00000  0.00784 0.01776 0.05460 0.00945 0.03443
#  100.00000 0.00848 0.01357 0.03912 0.00835 0.03175
#  110.00000 0.00803 0.00781 0.02272 0.00678 0.02637
#  120.00000 0.00703 0.00605 0.02213 0.00635 0.02403
#  130.00000 0.00770 0.00721 0.02946 0.00724 0.02368
#  140.00000 0.01187 0.00890 0.03321 0.00909 0.02339
#  150.00000 0.01789 0.00996 0.03224 0.01097 0.02452
#  160.00000 0.02302 0.00983 0.02926 0.01182 0.02968
#  170.00000 0.02352 0.00897 0.03202 0.01056 0.04313,
#               CBF1    GAL4    SWI5   GAL80    ASH1
#  Time
#  0.00000   0.00310 0.00328 0.00231 0.00372 0.00611
#  10.00000  0.00489 0.05995 0.01067 0.03874 0.02225
#  20.00000  0.00534 0.05870 0.02037 0.05731 0.01921
#  30.00000  0.00453 0.03577 0.02538 0.05517 0.01140
#  40.00000  0.00289 0.01997 0.02222 0.03323 0.00955
#  50.00000  0.00180 0.01328 0.01640 0.01020 0.01152
#  60.00000  0.00237 0.01136 0.01420 0.00334 0.01331
#  70.00000  0.00346 0.01140 0.01595 0.00632 0.01652
#  80.00000  0.00379 0.01138 0.01988 0.00903 0.02251
#  90.00000  0.00380 0.01093 0.02160 0.00970 0.02623
#  100.00000 0.00417 0.01010 0.01802 0.00882 0.02333
#  110.00000 0.00476 0.00897 0.01374 0.00737 0.01884
#  120.00000 0.00542 0.00767 0.01349 0.00623 0.01811
#  130.00000 0.00671 0.00628 0.01448 0.00532 0.01839
#  140.00000 0.00908 0.00519 0.01364 0.00464 0.01657
#  150.00000 0.01176 0.00582 0.01408 0.00568 0.01629
#  160.00000 0.01369 0.00887 0.01849 0.00914 0.02051
#  170.00000 0.01394 0.01093 0.02164 0.01105 0.02288]

# %%
# get all lags
exp_xcor = lag_id.xcorr_experiments(exp_inter, 1)
gene_list = list(raw_data.columns.values)
lags=lag_id.calc_edge_lag(exp_xcor, gene_list, 0.1, 0.8, timestep=1)
lags = lags[lags['Parent'] != lags['Child']]
edge_df = pd.DataFrame(lags['Lag'].values, index=lags['Edge'].values, columns=['Lag'])
edge_df
# Out:
#                   Lag
# (CBF1, GAL4)  0.00000
# (CBF1, SWI5)  0.00000
# (CBF1, GAL80) 0.00000
# (CBF1, ASH1)  0.00000
# (GAL4, CBF1)  0.00000
# (GAL4, SWI5)  0.00000
# (GAL4, GAL80) 0.00000
# (GAL4, ASH1)  0.00000
# (SWI5, CBF1)  0.00000
# (SWI5, GAL4)  0.00000
# (SWI5, GAL80) 0.00000
# (SWI5, ASH1)  2.00000
# (GAL80, CBF1) 0.00000
# (GAL80, GAL4) 0.00000
# (GAL80, SWI5) 0.00000
# (GAL80, ASH1) 0.00000
# (ASH1, CBF1)  0.00000
# (ASH1, GAL4)  0.00000
# (ASH1, SWI5)  0.00000
# (ASH1, GAL80) 0.00000

# %%
#get all true lags

def get_true_edges(gold_filename):
    evaluator = Evaluator(gold_filename, '\t')
    edges = evaluator.gs_flat.tolist()
    return edges, evaluator

goldstandard = '../data/invitro/cantone_switchon_interpolated_goldstandard.tsv'
true_edges, evaluator = get_true_edges(goldstandard)

edge_df[edge_df.index.isin(true_edges)]
# Out:
#                   Lag
# (CBF1, GAL4)  0.00000
# (GAL4, SWI5)  0.00000
# (GAL4, GAL80) 0.00000
# (SWI5, CBF1)  0.00000
# (SWI5, GAL80) 0.00000
# (SWI5, ASH1)  2.00000
# (GAL80, GAL4) 0.00000
# (ASH1, CBF1)  0.00000

# %%
f, axarr = plt.subplots(5, sharex=True)
f.set_size_inches(18.5, 10.5)
#plot specific gene names
parent="SWI5"
child="ASH1"
shift_num = 1
my_axis = [0,0.03]
for idx,exp in enumerate(exp_inter):
    for col in exp:
        gene_name = exp[col].name
        if (gene_name == parent):
            axarr[idx].plot(exp[col], '.-', label=gene_name)
            axarr[idx].set_ylim(my_axis)
            plt.legend()
        elif (gene_name == child):
            shifted = exp[col].shift(shift_num)
            axarr[idx].plot(shifted, '.-', label=gene_name)
            axarr[idx].set_ylim(my_axis)
            plt.legend()
# Out:
# /Users/jjw036/anaconda/lib/python3.4/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
